# %%
#Импортируем необходимые библиотеки
import os, cv2, random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns
# %matplotlib inline 

from keras.models import Sequential
from keras.layers import Dropout, Flatten, Convolution2D, MaxPooling2D, ZeroPadding2D, Dense, Activation
from keras.optimizers import RMSprop, Adam
from keras.callbacks import EarlyStopping
from keras import backend as K
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop

# %%
#Объявим константы
TRAIN_DIR = 'C:\\data\\fish\\train\\'
TEST_DIR = 'C:\\data\\fish\\test_stg1\\'
FISH_CLASSES = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']
ROWS = 90  #720
COLS = 160 #1280
CHANNELS = 3

# %%
def get_images(fish):
    """Загрузка изображний из файла"""
    fish_dir = TRAIN_DIR+'{}'.format(fish)
    images = [fish+'\\'+im for im in os.listdir(fish_dir)]
    return images

def read_image(src):
    """Чтение и изменение размера"""
    im = cv2.imread(src, cv2.IMREAD_COLOR)
    im = cv2.resize(im, (COLS, ROWS), interpolation=cv2.INTER_CUBIC)
    return im

#Посмотрим сколько изображений какого класса
files = []
y_all = []

for fish in FISH_CLASSES:
    fish_files = get_images(fish)
    files.extend(fish_files)
    
    y_fish = np.tile(fish, len(fish_files))
    y_all.extend(y_fish)
    print("{0} photos of {1}".format(len(fish_files), fish))
    
y_all = np.array(y_all)
# Out:
# 1719 photos of ALB
# 200 photos of BET
# 117 photos of DOL
# 67 photos of LAG
# 465 photos of NoF
# 299 photos of OTHER
# 176 photos of SHARK
# 734 photos of YFT

# %%
X_all = np.ndarray((len(files), ROWS, COLS, CHANNELS), dtype=np.uint8)

for i, im in enumerate(files): 
    X_all[i] = read_image(TRAIN_DIR+im)
    if i%1000 == 0: print('Processed {} of {}'.format(i, len(files)))

print(X_all.shape)
# Out:
# Processed 0 of 3777
# Processed 1000 of 3777
# Processed 2000 of 3777
# Processed 3000 of 3777
# (3777, 90, 160, 3)

# %%
# Перекодируе целевую переменную в OneHot
y_all = LabelEncoder().fit_transform(y_all)
y_all = to_categorical(y_all)

#Разделим на обучающую и тестовую выборку
X_train, X_valid, y_train, y_valid = train_test_split(X_all, y_all, 
                                                    test_size=0.2, random_state=23, 
                                                    stratify=y_all)

# %%
#Создадим модель
optimizer = RMSprop(learning_rate=1e-4)
objective = 'categorical_crossentropy'

def center_normalize(x):
    mean = tf.reduce_mean(x)
    std = tf.math.reduce_std(x)
    return (x - mean) / std

model = Sequential()

# Используем Activation с функцией normalize как слой
model.add(Activation(activation=center_normalize, input_shape=(ROWS, COLS, CHANNELS)))

# Первый блок сверточных слоёв
model.add(Conv2D(32, (5, 5), padding='same', activation='relu', data_format='channels_last'))
model.add(Conv2D(32, (5, 5), padding='same', activation='relu', data_format='channels_last'))
model.add(MaxPooling2D(pool_size=(2, 2), data_format='channels_last'))

# Второй блок сверточных слоёв
model.add(Conv2D(64, (3, 3), padding='same', activation='relu', data_format='channels_last'))
model.add(Conv2D(64, (3, 3), padding='same', activation='relu', data_format='channels_last'))
model.add(MaxPooling2D(pool_size=(2, 2), data_format='channels_last'))

# Третий блок сверточных слоёв
model.add(Conv2D(128, (3, 3), padding='same', activation='relu', data_format='channels_last'))
model.add(Conv2D(128, (3, 3), padding='same', activation='relu', data_format='channels_last'))
model.add(MaxPooling2D(pool_size=(2, 2), data_format='channels_last'))

# Четвертый блок сверточных слоёв
model.add(Conv2D(256, (3, 3), padding='same', activation='relu', data_format='channels_last'))
model.add(Conv2D(256, (3, 3), padding='same', activation='relu', data_format='channels_last'))
# Заменяем final max pooling на глобальный усредняющий слой
model.add(GlobalAveragePooling2D())

# Полносвязные слои
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

# Выходной слой
#model.add(Dense(len(FISH_CLASSES), activation='sigmoid'))
model.add(Dense(len(FISH_CLASSES), activation='softmax'))

# Компиляция модели
model.compile(loss=objective, optimizer=optimizer)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\activations\activation.py:26: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ activation_3 (Activation)            │ (None, 90, 160, 3)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_16 (Conv2D)                   │ (None, 90, 160, 32)         │           2,432 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 90, 160, 32)         │          25,632 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 45, 80, 32)          │               0 │
# ...

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=4, verbose=1, mode='auto')        
        
model.fit(X_train, y_train, batch_size=64, epochs=1,
              validation_split=0.2, verbose=1, shuffle=True, callbacks=[early_stopping])
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 225s 6s/step - loss: 1.9280 - val_loss: 1.6957

# %%
preds = model.predict(X_valid, verbose=1)
print("Validation Log Loss: {}".format(log_loss(y_valid, preds)))
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 20s 817ms/step
# Validation Log Loss: 1.6934627005422025

# %%
test_files = [im for im in os.listdir(TEST_DIR)]
test = np.ndarray((len(test_files), ROWS, COLS, CHANNELS), dtype=np.uint8)

for i, im in enumerate(test_files): 
    test[i] = read_image(TEST_DIR+im)
    
test_preds = model.predict(test, verbose=1)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 793ms/step

# %%
submission = pd.DataFrame(test_preds, columns=FISH_CLASSES)
submission.insert(0, 'image', test_files)
submission.head(10)
# Out:
#            image       ALB       BET       DOL       LAG       NoF     OTHER  \
# 0  img_00005.jpg  0.315403  0.099259  0.061416  0.067428  0.126872  0.087309
# 1  img_00007.jpg  0.278452  0.105435  0.070711  0.076532  0.129553  0.095059
# 2  img_00009.jpg  0.253265  0.109569  0.077454  0.082970  0.130784  0.100303
# 3  img_00018.jpg  0.317810  0.098688  0.061108  0.067080  0.126575  0.087032
# 4  img_00027.jpg  0.294199  0.102995  0.066277  0.072215  0.128493  0.091885
# 5  img_00030.jpg  0.296270  0.102677  0.066216  0.072115  0.128280  0.091008
# 6  img_00040.jpg  0.291004  0.103592  0.067208  0.073067  0.128640  0.092536
# 7  img_00046.jpg  0.332371  0.096289  0.057646  0.063663  0.125281  0.083838
# 8  img_00053.jpg  0.370908  0.089101  0.049731  0.055626  0.120830  0.076472
# 9  img_00071.jpg  0.283002  0.104701  0.069585  0.075381  0.129255  0.093945
#
#       SHARK       YFT
# 0  0.057399  0.184915
# 1  0.066757  0.177501
# 2  0.073755  0.171900
# 3  0.056911  0.184796
# ...

# %%
#Импортируем результат в файл
submission.to_csv("submission.csv", index=False)

# %%
# Количество изображений для отображения
num_display = 5

# Визуализируем каждое изображение и его предсказания
for i in range(num_display):
    plt.figure(figsize=(14, 6))
    
    # Отображение изображения
    plt.subplot(1, 2, 1)
    # Обратите внимание: изображения могут быть в формате BGR, если так, конвертируем в RGB
    plt.imshow(cv2.cvtColor(test[i], cv2.COLOR_BGR2RGB))
    plt.title(f"Изображение: {test_files[i]}")
    plt.axis('off')
    
    # Вероятности предсказаний
    class_probs = test_preds[i]
    classes = FISH_CLASSES
    
    # Построение горизонтальной диаграммы вероятностей
    plt.subplot(1, 2, 2)
    sns.barplot(x=class_probs, y=classes)
    plt.xlabel('Вероятность')
    plt.title('Предсказанные вероятности')
    plt.xlim(0, 1)
    
    plt.tight_layout()
    plt.show()
